# %%
import pandas as pd

pd.set_option('display.max_rows', 6000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 1000)

# %%
path_output = '/nfs/home/vyasa/projects/proj_off/data_off/clarify/spanish_comorbidity/new/output_biofalcon_slow/'

df = pd.read_csv(path_output+'train_MEV_ents_jaccard.csv', encoding='utf-8')

# %%
df.head(5)
# Out:
#   Value_ID                                value  IsValueReplaced  \
# 0   A10000                    Gastritis crÛnica            False
# 1   A10001  Sarcoma PleomÛrfico Pectoral Mayor              True
# 2   A10002                        hiperuricemia            False
# 3   A10003             intervenido pÛlipo colon            False
# 4   A10004          intervenido estenosis aorta            False
#
#                      value_witht_abbr                           replacement  \
# 0                   Gastritis crÛnica                     Chronic Gastritis
# 1  Sarcoma PleomÛrfico Pectoral Mayor  Pectoralis Major Pleomorphic Sarcoma
# 2                       hiperuricemia                         Hyperuricemia
# 3            intervenido pÛlipo colon                  Colon Polyp Operated
# 4         intervenido estenosis aorta              Aortic Stenosis Operated
#
#                                  google  \
# 0                     Chronic Gastritis
# ...

# %%
df.columns
# Out:
# Index(['Value_ID', 'value', 'IsValueReplaced', 'value_witht_abbr',
#        'replacement', 'google', 'deepl', 'google_abbr', 'deepl_abbr',
#        'google_withst_num', 'deepl_withst_num', 'google_abbr_withst_num',
#        'deepl_abbr_withst_num', 'haveAbbr', 'stop_words_google_len',
#        'stop_words_deepl_len', 'stop_words_google_abbr_len',
#        'stop_words_deepl_abbr_len', 'value_ents', 'value_abbr_ents', 'ents',
#        'google_ents', 'deepl_ents', 'google_abbr_ents', 'deepl_abbr_ents',
#        'value_ents_len', 'value_abbr_ents_len', 'ents_len', 'google_ents_len',
#        'deepl_ents_len', 'google_abbr_ents_len', 'deepl_abbr_ents_len',
#        'value_cui_score', 'value_abbr_cui_score', 'mev_cui_score',
#        'google_cui_score', 'deepl_cui_score', 'google_abbr_cui_score',
#        'deepl_abbr_cui_score', 'value_cui_len', 'value_abbr_cui_len',
#        'mev_cui_len', 'google_cui_len', 'deepl_cui_len', 'google_abbr_cui_len',
# ...

# %%
df[['value_ents_len','value_abbr_ents_len','ents_len', 'google_ents_len', 'deepl_ents_len', 'google_abbr_ents_len', 'deepl_abbr_ents_len']].hist(figsize=(15,5), layout=(1,7))
# Out:
# array([[<AxesSubplot:title={'center':'value_ents_len'}>,
#         <AxesSubplot:title={'center':'value_abbr_ents_len'}>,
#         <AxesSubplot:title={'center':'ents_len'}>,
#         <AxesSubplot:title={'center':'google_ents_len'}>,
#         <AxesSubplot:title={'center':'deepl_ents_len'}>,
#         <AxesSubplot:title={'center':'google_abbr_ents_len'}>,
#         <AxesSubplot:title={'center':'deepl_abbr_ents_len'}>]],
#       dtype=object)

# %%
df[['stop_words_google_len', 'stop_words_deepl_len', 'stop_words_google_abbr_len', 'stop_words_deepl_abbr_len']].hist(figsize=(16,4), layout=(1,4))
# Out:
# array([[<AxesSubplot:title={'center':'stop_words_google_len'}>,
#         <AxesSubplot:title={'center':'stop_words_deepl_len'}>,
#         <AxesSubplot:title={'center':'stop_words_google_abbr_len'}>,
#         <AxesSubplot:title={'center':'stop_words_deepl_abbr_len'}>]],
#       dtype=object)

# %%
df[['value_cui_len','value_abbr_cui_len','mev_cui_len','google_cui_len', 'deepl_cui_len', 'google_abbr_cui_len', 'deepl_abbr_cui_len']].hist(figsize=(15,5), layout=(1,7))
# Out:
# array([[<AxesSubplot:title={'center':'value_cui_len'}>,
#         <AxesSubplot:title={'center':'value_abbr_cui_len'}>,
#         <AxesSubplot:title={'center':'mev_cui_len'}>,
#         <AxesSubplot:title={'center':'google_cui_len'}>,
#         <AxesSubplot:title={'center':'deepl_cui_len'}>,
#         <AxesSubplot:title={'center':'google_abbr_cui_len'}>,
#         <AxesSubplot:title={'center':'deepl_abbr_cui_len'}>]],
#       dtype=object)

# %%
df[['cui_jacD_mev_google', 'cui_jacD_mev_deepl', 'cui_jacD_mev_google_abbr', 'cui_jacD_mev_deepl_abbr']].hist(figsize=(15,5), layout=(1,5))
# Out:
# array([[<AxesSubplot:title={'center':'cui_jacD_mev_google'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_deepl'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_google_abbr'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_deepl_abbr'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
df[['cui_jacD_mev_google_A', 'cui_jacD_mev_deepl_A', 'cui_jacD_mev_google_abbr_A', 'cui_jacD_mev_deepl_abbr_A']].hist(figsize=(16,4), layout=(1,4))
# Out:
# array([[<AxesSubplot:title={'center':'cui_jacD_mev_google_A'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_deepl_A'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_google_abbr_A'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_deepl_abbr_A'}>]],
#       dtype=object)

# %%
df[['cui_jacD_mev_google_withst_num', 'cui_jacD_mev_deepl_withst_num', 'cui_jacD_mev_google_abbr_withst_num', 'cui_jacD_mev_deepl_abbr_withst_num']].hist(figsize=(16,4), layout=(1,4))
# Out:
# array([[<AxesSubplot:title={'center':'cui_jacD_mev_google_withst_num'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_deepl_withst_num'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_google_abbr_withst_num'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_deepl_abbr_withst_num'}>]],
#       dtype=object)

# %%
df[['cui_jacD_mev_google_withst_num_A', 'cui_jacD_mev_deepl_withst_num_A', 'cui_jacD_mev_google_abbr_withst_num_A', 'cui_jacD_mev_deepl_abbr_withst_num_A']].hist(figsize=(16,4), layout=(1,4))
# Out:
# array([[<AxesSubplot:title={'center':'cui_jacD_mev_google_withst_num_A'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_deepl_withst_num_A'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_google_abbr_withst_num_A'}>,
#         <AxesSubplot:title={'center':'cui_jacD_mev_deepl_abbr_withst_num_A'}>]],
#       dtype=object)

# %%
df[['ents_len', 'google_ents_len', 'deepl_ents_len', 'google_cui_len', 'deepl_cui_len','mev_cui_len', 'cui_jacD_mev_google', 'cui_jacD_mev_deepl','cui_jacD_mev_google_withst_num', 'cui_jacD_mev_deepl_withst_num']].describe()
# Out:
#           ents_len  google_ents_len  deepl_ents_len  google_cui_len  \
# count  1589.000000      1589.000000     1589.000000     1589.000000
# mean      1.595343         2.648836        2.626809        2.648836
# std       1.111766         1.747984        1.712250        1.747984
# min       1.000000         0.000000        0.000000        0.000000
# 25%       1.000000         1.000000        1.000000        1.000000
# 50%       1.000000         2.000000        2.000000        2.000000
# 75%       2.000000         3.000000        3.000000        3.000000
# max      12.000000        13.000000       12.000000       13.000000
#
#        deepl_cui_len  mev_cui_len  cui_jacD_mev_google  cui_jacD_mev_deepl  \
# count    1589.000000  1589.000000          1589.000000         1589.000000
# mean        2.626809     1.595343             0.337619            0.343448
# std         1.712250     1.111766             0.390311            0.393086
# ...

# %%
df[['ents_len', 'google_abbr_ents_len', 'deepl_abbr_ents_len', 'google_abbr_cui_len', 'deepl_abbr_cui_len','mev_cui_len', 'cui_jacD_mev_google_abbr', 'cui_jacD_mev_deepl_abbr','cui_jacD_mev_google_abbr_withst_num', 'cui_jacD_mev_deepl_abbr_withst_num']].describe()
# Out:
#           ents_len  google_abbr_ents_len  deepl_abbr_ents_len  \
# count  1589.000000           1589.000000          1589.000000
# mean      1.595343              3.057898             3.072373
# std       1.111766              2.109215             2.132966
# min       1.000000              0.000000             0.000000
# 25%       1.000000              1.000000             1.000000
# 50%       1.000000              3.000000             3.000000
# 75%       2.000000              4.000000             4.000000
# max      12.000000             15.000000            16.000000
#
#        google_abbr_cui_len  deepl_abbr_cui_len  mev_cui_len  \
# count          1589.000000         1589.000000  1589.000000
# mean              3.057898            3.072373     1.595343
# std               2.109215            2.132966     1.111766
# min               0.000000            0.000000     1.000000
# 25%               1.000000            1.000000     1.000000
# ...

# %%
df[['cui_jacD_mev_google_withst_num_A', 'cui_jacD_mev_deepl_withst_num_A', 'cui_jacD_mev_google_A', 'cui_jacD_mev_deepl_A']].describe()
# Out:
#        cui_jacD_mev_google_withst_num_A  cui_jacD_mev_deepl_withst_num_A  \
# count                       1589.000000                      1589.000000
# mean                           0.498353                         0.503084
# std                            0.472049                         0.474495
# min                            0.000000                         0.000000
# 25%                            0.000000                         0.000000
# 50%                            0.500000                         0.500000
# 75%                            1.000000                         1.000000
# max                            1.000000                         1.000000
#
#        cui_jacD_mev_google_A  cui_jacD_mev_deepl_A
# count            1589.000000           1589.000000
# mean                0.491478              0.496423
# std                 0.471726              0.474685
# min                 0.000000              0.000000
# 25%                 0.000000              0.000000
# ...

# %%
df[['cui_jacD_mev_google_abbr_withst_num_A', 'cui_jacD_mev_deepl_abbr_withst_num_A', 'cui_jacD_mev_google_abbr_A', 'cui_jacD_mev_deepl_abbr_A']].describe()
# Out:
#        cui_jacD_mev_google_abbr_withst_num_A  \
# count                            1589.000000
# mean                                0.561029
# std                                 0.466116
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.750000
# 75%                                 1.000000
# max                                 1.000000
#
#        cui_jacD_mev_deepl_abbr_withst_num_A  cui_jacD_mev_google_abbr_A  \
# count                           1589.000000                 1589.000000
# mean                               0.562534                    0.554757
# std                                0.466664                    0.466762
# min                                0.000000                    0.000000
# 25%                                0.000000                    0.000000
# 50%                                0.750000                    0.750000
# ...

# %%
df[df['mev_cui_len']==0][['value', 'value_witht_abbr', 'replacement']].to_csv(path_output+'train_MEV_left_19_05.csv', encoding='utf-8')

# %%
df[df['mev_cui_len']==0]
# Out:
# Empty DataFrame
# ...

# %%
# Stop words
df.groupby(['stop_words_google_len'])['ents_len','google_ents_len','google_cui_len', 'cui_jacD_mev_google', 'cui_jacD_mev_google_A'].agg(['count', 'mean' , 'std', 'max'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                       ents_len                         google_ents_len  \
#                          count      mean       std max           count
# stop_words_google_len
# 0                         1566  1.598340  1.105997  12            1566
# 1                           22  1.409091  1.501082   8              22
# 2                            1  1.000000       NaN   1               1
#
#                                               google_cui_len            \
#                            mean       std max          count      mean
# stop_words_google_len
# 0                      2.630907  1.734938  13           1566  2.630907
# 1                      3.863636  2.252944   8             22  3.863636
# ...

# %%
df.groupby(['stop_words_deepl_len'])['ents_len','deepl_ents_len','deepl_cui_len', 'cui_jacD_mev_deepl','cui_jacD_mev_deepl_A'].agg(['count', 'mean' , 'std', 'max'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      ents_len                         deepl_ents_len  \
#                         count      mean       std max          count
# stop_words_deepl_len
# 0                        1565  1.597444  1.105783  12           1565
# 1                          24  1.458333  1.473805   8             24
#
#                                              deepl_cui_len            \
#                           mean       std max         count      mean
# stop_words_deepl_len
# 0                     2.610863  1.695491  12          1565  2.610863
# 1                     3.666667  2.407717   9            24  3.666667
#
#                                    cui_jacD_mev_deepl                      \
# ...

# %%
df.groupby(['stop_words_google_abbr_len'])['ents_len','google_abbr_ents_len','google_abbr_cui_len', 'cui_jacD_mev_google_abbr','cui_jacD_mev_google_abbr_A'].agg(['count', 'mean' , 'std', 'max'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                            ents_len                          \
#                               count      mean       std max
# stop_words_google_abbr_len
# 0                              1564  1.599105  1.106498  12
# 1                                24  1.375000  1.438976   8
# 2                                 1  1.000000       NaN   1
#
#                            google_abbr_ents_len                          \
#                                           count      mean       std max
# stop_words_google_abbr_len
# 0                                          1564  3.046036  2.104847  15
# 1                                            24  3.791667  2.340181   8
# ...

# %%
df.groupby(['stop_words_deepl_abbr_len'])['ents_len','deepl_abbr_ents_len','deepl_abbr_cui_len', 'cui_jacD_mev_deepl_abbr','cui_jacD_mev_deepl_abbr_A'].agg(['count', 'mean' , 'std', 'max'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                           ents_len                          \
#                              count      mean       std max
# stop_words_deepl_abbr_len
# 0                             1562  1.598592  1.106534  12
# 1                               27  1.407407  1.393923   8
#
#                           deepl_abbr_ents_len                          \
#                                         count      mean       std max
# stop_words_deepl_abbr_len
# 0                                        1562  3.068502  2.131439  16
# 1                                          27  3.296296  2.250040   9
#
#                           deepl_abbr_cui_len                          \
# ...

# %%
df.groupby(['haveAbbr'])['google_ents_len','deepl_ents_len','google_cui_len','deepl_cui_len'].agg(['count', 'mean' , 'std', 'max'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#          google_ents_len                         deepl_ents_len            \
#                    count      mean       std max          count      mean
# haveAbbr
# False               1387  2.506128  1.621620  13           1387  2.504686
# True                 202  3.628713  2.213879  13            202  3.465347
#
#                        google_cui_len                         deepl_cui_len  \
#                std max          count      mean       std max         count
# haveAbbr
# False     1.631826  12           1387  2.506128  1.621620  13          1387
# True      1.997831  10            202  3.628713  2.213879  13           202
#
#
#               mean       std max
# haveAbbr
# ...

# %%
df.groupby(['haveAbbr'])['cui_jacD_mev_google','cui_jacD_mev_deepl','cui_jacD_mev_google_A', 'cui_jacD_mev_deepl_A'].agg(['count', 'mean' , 'std'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#          cui_jacD_mev_google                     cui_jacD_mev_deepl            \
#                        count      mean       std              count      mean
# haveAbbr
# False                   1387  0.360382  0.399384               1387  0.361588
# True                     202  0.181319  0.274898                202  0.218896
#
#                    cui_jacD_mev_google_A                      \
#                std                 count      mean       std
# haveAbbr
# False     0.401454                  1387  0.513440  0.474614
# True      0.302623                   202  0.340677  0.422612
#
#          cui_jacD_mev_deepl_A
#                         count      mean       std
# haveAbbr
# ...

# %%
df.groupby(['IsValueReplaced'])['google_ents_len','deepl_ents_len','google_cui_len','deepl_cui_len'].agg(['count', 'mean' , 'std', 'max'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 google_ents_len                         deepl_ents_len  \
#                           count      mean       std max          count
# IsValueReplaced
# False                      1157  2.305099  1.512720  10           1157
# True                        432  3.569444  1.988317  13            432
#
#                                         google_cui_len                      \
#                      mean       std max          count      mean       std
# IsValueReplaced
# False            2.326707  1.554796  11           1157  2.305099  1.512720
# True             3.430556  1.851767  12            432  3.569444  1.988317
#
#                     deepl_cui_len
# ...

# %%
df.groupby(['IsValueReplaced'])['google_abbr_ents_len','deepl_abbr_ents_len','google_abbr_cui_len','deepl_abbr_cui_len'].agg(['count', 'mean' , 'std', 'max'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 google_abbr_ents_len                          \
#                                count      mean       std max
# IsValueReplaced
# False                           1157  2.305099  1.501815  10
# True                             432  5.074074  2.178587  15
#
#                 deepl_abbr_ents_len                          \
#                               count      mean       std max
# IsValueReplaced
# False                          1157  2.319793  1.549550  11
# True                            432  5.087963  2.174871  16
#
#                 google_abbr_cui_len                          \
#                               count      mean       std max
# IsValueReplaced
# ...

# %%
df.groupby(['IsValueReplaced'])['cui_jacD_mev_google','cui_jacD_mev_deepl','cui_jacD_mev_google_A', 'cui_jacD_mev_deepl_A'].agg(['count', 'mean' , 'std'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 cui_jacD_mev_google                     cui_jacD_mev_deepl  \
#                               count      mean       std              count
# IsValueReplaced
# False                          1157  0.396706  0.415360               1157
# True                            432  0.179368  0.253169                432
#
#                                     cui_jacD_mev_google_A                      \
#                      mean       std                 count      mean       std
# IsValueReplaced
# False            0.399699  0.418637                  1157  0.546219  0.478618
# True             0.192796  0.260779                   432  0.344869  0.419387
#
# ...

# %%
df.groupby(['IsValueReplaced'])['cui_jacD_mev_google_abbr','cui_jacD_mev_deepl_abbr','cui_jacD_mev_google_abbr_A', 'cui_jacD_mev_deepl_abbr_A']
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df.groupby(['IsValueReplaced'])['cui_jacD_mev_google_deepl_com','cui_jacD_mev_google_deepl_abbr_com', 'cui_jacD_mev_google_deepl_com_A','cui_jacD_mev_google_deepl_abbr_com_A'].agg(['count', 'mean' , 'std'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 cui_jacD_mev_google_deepl_com                      \
#                                         count      mean       std
# IsValueReplaced
# False                                    1157  0.383502  0.420290
# True                                      432  0.179121  0.258905
#
#                 cui_jacD_mev_google_deepl_abbr_com                      \
#                                              count      mean       std
# IsValueReplaced
# False                                         1157  0.381044  0.418823
# True                                           432  0.289619  0.301307
#
#                 cui_jacD_mev_google_deepl_com_A                      \
# ...

# %%
df.groupby(['IsValueReplaced'])['cui_jacD_mev_google_deepl_un','cui_jacD_mev_google_deepl_abbr_un', 'cui_jacD_mev_google_deepl_un_A', 'cui_jacD_mev_google_deepl_abbr_un_A'].agg(['count', 'mean' , 'std'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 cui_jacD_mev_google_deepl_un                      \
#                                        count      mean       std
# IsValueReplaced
# False                                   1157  0.395784  0.402552
# True                                     432  0.183919  0.242453
#
#                 cui_jacD_mev_google_deepl_abbr_un                      \
#                                             count      mean       std
# IsValueReplaced
# False                                        1157  0.396012  0.403556
# True                                          432  0.288690  0.282780
#
#                 cui_jacD_mev_google_deepl_un_A                      \
# ...

# %%
df.groupby(['IsValueReplaced'])['cui_OC_mev_value', 'cui_OC_mev_value_abbr','cui_OC_mev_google','cui_OC_mev_deepl', 'cui_OC_mev_google_abbr', 'cui_OC_mev_deepl_abbr'].agg(['count', 'mean' , 'std'])
# Out:
# /nfs/home/vyasa/software/pkg/miniconda3/envs/scispacy_0.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 cui_OC_mev_value                     cui_OC_mev_value_abbr  \
#                            count      mean       std                 count
# IsValueReplaced
# False                       1128  0.388143  0.457893                  1128
# True                         432  0.237442  0.368881                   432
#
#                                     cui_OC_mev_google                      \
#                      mean       std             count      mean       std
# IsValueReplaced
# False            0.388143  0.457893              1128  0.574141  0.480126
# True             0.237442  0.368881               430  0.356757  0.424562
#
# ...

# %%
df.to_csv(path_output+'isValueReplaced_dataAnalysis.csv', index=True, encoding='utf-8')

# %%
df[['cui_OC_mev_value', 'cui_OC_mev_value_abbr','cui_OC_mev_google_abbr', 'cui_OC_mev_deepl_abbr', 'cui_jacD_mev_value','cui_jacD_mev_value_abbr','cui_jacD_mev_google_abbr', 'cui_jacD_mev_deepl_abbr','cui_jacD_mev_google_deepl_abbr_un','cui_jacD_mev_google_abbr_A', 'cui_jacD_mev_deepl_abbr_A','cui_jacD_mev_google_deepl_abbr_un_A']].agg(['count', 'mean' , 'std'])
# Out:
#        cui_OC_mev_value  cui_OC_mev_value_abbr  cui_OC_mev_google_abbr  \
# count       1560.000000            1560.000000             1558.000000
# mean           0.346410               0.346410                0.577163
# std            0.440155               0.440155                0.467234
#
#        cui_OC_mev_deepl_abbr  cui_jacD_mev_value  cui_jacD_mev_value_abbr  \
# count            1555.000000         1589.000000              1589.000000
# mean                0.580524            0.192867                 0.199721
# std                 0.468324            0.304949                 0.301787
#
#        cui_jacD_mev_google_abbr  cui_jacD_mev_deepl_abbr  \
# count               1589.000000              1589.000000
# mean                   0.366484                 0.370002
# std                    0.388162                 0.389519
#
#        cui_jacD_mev_google_deepl_abbr_un  cui_jacD_mev_google_abbr_A  \
# count                        1589.000000                 1589.000000
# ...
